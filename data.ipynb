# %% [raw]
# ---
# title: "Experimental data of *S. elongatus*: gathering, aggregation, analysis, visualization"
# format: html
# ---

# %% [markdown]
# # Data gathering
#
# In this part, we will gather as much as possible proteomics data from published literature and databases. Here are some sources:
#
# 1. CyanoMapDB, this is a database providing cyanobacterial PPIs with experimental evidence, consisting of 52,304 PPIs among 6,789 proteins from 23 cyanobacterial species. It collected available data in UniProt, STRING, and IntAct, and mined numerous PPIs from co-fractionation MS data in cyanobacteria.
# 2. Native Protein Complexes in Synechocystis sp. PCC 6803, Comparative Network Biology Discovers Protein Complexes That Underline Cellular Differentiation in Anabaena sp.; These two papers talk about how to construct the complexes using interactome data and clustering method. Our approach will be the same to use the same clustering method to analyze the CyanoMapDB interactome data of S. elongatus PCC7942
# 3. There are some cofraction proteomics data of S. elongatus PCC7942 reported from the paper: "Monitoring light/dark association dynamics of multi-protein complexes in cyanobacteria using size exclusion chromatography-based proteomics". The CyanoMapDB included this dataset and use it predicted the interactome.

# %%
import pandas as pd
import os, sys, re
from pathlib import Path
home = str(Path.home())

# %%
work_dir = home + "/Dropbox/PNNL/PredPheno/SystemModeling/Modeling/S_elongatus"
# work_dir

# %%
proteome = pd.read_excel(work_dir + "/data/interactome/Synechococcus_PCC_7942_Dataset.xlsx", sheet_name="Protein")
interactome = pd.read_excel(work_dir + "/data/interactome/Synechococcus_PCC_7942_Dataset.xlsx", sheet_name="PPI")

# %%
interactome
# Out:
#      Protein A Protein B                                              Taxon  \
# 0       O05161    P16954  Synechococcus elongatus (strain PCC 7942 / FAC...
# 1       O05161    Q31KN7  Synechococcus elongatus (strain PCC 7942 / FAC...
# 2       O05161    Q31LJ5  Synechococcus elongatus (strain PCC 7942 / FAC...
# 3       O05161    Q31LM9  Synechococcus elongatus (strain PCC 7942 / FAC...
# 4       O05161    Q31N38  Synechococcus elongatus (strain PCC 7942 / FAC...
# ...        ...       ...                                                ...
# 4529    Q8GMR7    Q99QJ5  Synechococcus elongatus (strain PCC 7942 / FAC...
# 4530    Q8GMT0    Q935Z3  Synechococcus elongatus (strain PCC 7942 / FAC...
# 4531    Q8KPQ0    Q9L4P3  Synechococcus elongatus (strain PCC 7942 / FAC...
# 4532    Q8KPU9    Q8L1E5  Synechococcus elongatus (strain PCC 7942 / FAC...
# 4533    Q9R6W2    Q9Z3H5  Synechococcus elongatus (strain PCC 7942 / FAC...
#
#      UniProt evidence  STRING score  IntAct score IntAct method  \
# 0                 NaN           NaN           NaN           NaN
# 1                 NaN           NaN           NaN           NaN
# 2                 NaN           NaN           NaN           NaN
# 3                 NaN           NaN           NaN           NaN
# 4                 NaN           NaN           NaN           NaN
# ...               ...           ...           ...           ...
# 4529              NaN           NaN           NaN           NaN
# 4530              NaN           NaN           NaN           NaN
# 4531              NaN           NaN           NaN           NaN
# 4532              NaN           NaN           NaN           NaN
# 4533              NaN           NaN           NaN           NaN
#
#       GS complex evidence  CF-MS score CF-MS ID A CF-MS ID B  PPI index
# 0                     NaN        0.651      1G6TR      1G1IW      0.651
# 1                     NaN        0.595      1G6TR      1G152      0.595
# 2                     NaN        0.694      1G6TR      1G2EH      0.694
# 3                     NaN        0.639      1G6TR      1G4ZP      0.639
# 4                     NaN        0.647      1G6TR      1GCIT      0.647
# ...                   ...          ...        ...        ...        ...
# 4529                  NaN        0.598      1G0PI      1G030      0.598
# 4530                  NaN        0.849      1G6TX      1G1IA      0.849
# 4531                  NaN        0.675      1G0ND      1G126      0.675
# 4532                  NaN        0.696      1G15V      1G1X2      0.696
# 4533                  NaN        0.776      1G0V1      1G6RH      0.776
#
# [4534 rows x 12 columns]

# %%
cl1_input = interactome[["Protein A", "Protein B", "PPI index"]]
input_file = work_dir + "/data/interactome/ClusterONE_input.tsv"
cl1_input.to_csv(input_file, sep='\t', index=None, header=None)

# %%
import subprocess
output_file = work_dir + "/data/interactome/ClusterONE_output.tsv"
output_file_csv = work_dir + "/data/interactome/ClusterONE_output.csv"
with open(output_file, 'w') as output:
    subprocess.run(["java", "-jar", home + "/Dropbox/PNNL/PredPheno/SystemModeling/tools/cluster_one-1.2.jar", "-f", "edge_list", "-F", "plain", input_file], stdout=output)
with open(output_file_csv, 'w') as output:
    subprocess.run(["java", "-jar", home + "/Dropbox/PNNL/PredPheno/SystemModeling/tools/cluster_one-1.2.jar", "-f", "edge_list", "-F", "csv", input_file], stdout=output)
# Out:
# [====================] 100% Reading graph...
# Loaded graph with 679 nodes and 4534 edges
# [====================] 100% Choosing density thresold...
# [====================] 100% Growing clusters from seeds using 10 threads...
# [====================] 100% Indexing clusters...
# [====================] 100% Merging highly overlapping clusters...
# Detected 129 complexes
# [====================] 100% Reading graph...
# Loaded graph with 679 nodes and 4534 edges
# [====================] 100% Choosing density thresold...
# [====================] 100% Growing clusters from seeds using 10 threads...
# [====================] 100% Indexing clusters...
# [====================] 100% Merging highly overlapping clusters...
# Detected 129 complexes

# %%
sys.path.append("./data/interactome")
import utils3 as util3

# %%
import GoldStandard as GS
# Evaluating predicted clusters
pred_clusters = GS.Clusters(False)
pred_clusters.read_file(output_file)
# Out:
# Average size of predicted complexes is: 8.410852713178295

# %%
network_df = pd.read_csv(input_file, sep='\t', header=None)
network_df.shape
# Out:
# (4534, 3)

# %%
network_df.columns = ["ProtA", "ProtB", "Score"]

# %%
edge_idx = []
clusters = pred_clusters
for complex in clusters.complexes:
    prots = list(clusters.complexes[complex])
    edge_idx += [i for i in range(network_df.shape[0]) if network_df.iloc[i,0] in prots and network_df.iloc[i,1] in prots]
edge_idx = list(set(edge_idx))
complexes_df = network_df.iloc[edge_idx, :].copy()

# %%
complexes_df
# Out:
#        ProtA   ProtB  Score
# 3     O05161  Q31LM9  0.639
# 7     O05161  Q935Z3  0.675
# 11    O06865  P43087  0.811
# 13    O06865  Q31KE9  0.716
# 19    O06865  Q31N85  0.693
# ...      ...     ...    ...
# 4528  Q8GMR4  Q8GMR7  0.751
# 4529  Q8GMR7  Q99QJ5  0.598
# 4530  Q8GMT0  Q935Z3  0.849
# 4531  Q8KPQ0  Q9L4P3  0.675
# 4533  Q9R6W2  Q9Z3H5  0.776
#
# [2815 rows x 3 columns]

# %%
network_df["network"] = network_df[0].astype(str) + '\t' + network_df[1].astype(str) + '\t' + network_df[2].astype(str)

# %%
network = network_df["network"].to_list()

# %%
clust_json, clust_edges, clust_nodes = util3.clusters_to_json(pred_clusters, network)

# %%
clust_js = util3.json_to_cy_js("clust_cy", clust_json)
# clust_cy_div = """<div id='clust_cy' style="width: 100%; height: 500px; background: #f0f0f0;"></div>"""
# clust_js

# %%
from IPython.display import HTML, display, Javascript
display(HTML(clust_cy_div))
Javascript(clust_js)
# Out:
# <div id='clust_cy' style="width: 100%; height: 500px; background: #f0f0f0;"></div>

# %%
import ipycytoscape
import ipywidgets as wigets
cytoscapeobj = ipycytoscape.CytoscapeWidget()
import json
net_json = json.loads(clust_json)

# %%
net_json
# Out:
# [{'group': 'edges',
#   'data': {'source': 'Q31R70_0', 'target': 'Q55357_0', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31R70_0', 'target': 'Q31LU5_0', 'score': 0.666}},
#  {'group': 'edges',
#   'data': {'source': 'Q31R70_0', 'target': 'Q31RZ4_0', 'score': 0.782}},
#  {'group': 'edges',
#   'data': {'source': 'Q31R70_0', 'target': 'Q31NZ1_0', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31R70_0', 'target': 'Q31RZ5_0', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31R70_0', 'target': 'Q31PC1_0', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q55357_0', 'target': 'Q31LU5_0', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q55357_0', 'target': 'Q31RZ4_0', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q55357_0', 'target': 'Q31NZ1_0', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q55357_0', 'target': 'Q31RZ5_0', 'score': 0.758}},
#  {'group': 'edges',
#   'data': {'source': 'Q55357_0', 'target': 'Q31PC1_0', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LU5_0', 'target': 'Q31RZ4_0', 'score': 0.923}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LU5_0', 'target': 'Q31NZ1_0', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LU5_0', 'target': 'Q31RZ5_0', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LU5_0', 'target': 'Q31PC1_0', 'score': 0.804}},
#  {'group': 'edges',
#   'data': {'source': 'Q31RZ4_0', 'target': 'Q31NZ1_0', 'score': 0.779}},
#  {'group': 'edges',
#   'data': {'source': 'Q31RZ4_0', 'target': 'Q31RZ5_0', 'score': 0.717}},
#  {'group': 'edges',
#   'data': {'source': 'Q31RZ4_0', 'target': 'Q31PC1_0', 'score': 0.813}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NZ1_0', 'target': 'Q31RZ5_0', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NZ1_0', 'target': 'Q31PC1_0', 'score': 0.804}},
#  {'group': 'edges',
#   'data': {'source': 'Q31RZ5_0', 'target': 'Q31PC1_0', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31Q05_1', 'target': 'Q31NB2_1', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31Q05_1', 'target': 'Q31RK2_1', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31Q05_1', 'target': 'Q31NB3_1', 'score': 0.95}},
#  {'group': 'edges',
#   'data': {'source': 'Q31Q05_1', 'target': 'Q03513_1', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31Q05_1', 'target': 'Q03511_1', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31Q05_1', 'target': 'Q03512_1', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NB2_1', 'target': 'Q31RK2_1', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NB2_1', 'target': 'Q31NB3_1', 'score': 0.996}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NB2_1', 'target': 'Q03513_1', 'score': 0.989}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NB2_1', 'target': 'Q03511_1', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NB2_1', 'target': 'Q03512_1', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31RK2_1', 'target': 'Q31NB3_1', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31RK2_1', 'target': 'Q03513_1', 'score': 0.718}},
#  {'group': 'edges',
#   'data': {'source': 'Q31RK2_1', 'target': 'Q03511_1', 'score': 0.793}},
#  {'group': 'edges',
#   'data': {'source': 'Q31RK2_1', 'target': 'Q03512_1', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NB3_1', 'target': 'Q03513_1', 'score': 0.99}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NB3_1', 'target': 'Q03511_1', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NB3_1', 'target': 'Q03512_1', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q03513_1', 'target': 'Q03511_1', 'score': 0.911}},
#  {'group': 'edges',
#   'data': {'source': 'Q03513_1', 'target': 'Q03512_1', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q03511_1', 'target': 'Q03512_1', 'score': 0.776}},
#  {'group': 'edges',
#   'data': {'source': 'Q31MN6_2', 'target': 'Q8GJM0_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31MN6_2', 'target': 'Q31PN3_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31MN6_2', 'target': 'Q31N39_2', 'score': 0.761}},
#  {'group': 'edges',
#   'data': {'source': 'Q31MN6_2', 'target': 'Q31K19_2', 'score': 0.813}},
#  {'group': 'edges',
#   'data': {'source': 'Q31MN6_2', 'target': 'Q31PQ2_2', 'score': 0.768}},
#  {'group': 'edges',
#   'data': {'source': 'Q31MN6_2', 'target': 'Q31MI8_2', 'score': 0.784}},
#  {'group': 'edges',
#   'data': {'source': 'Q31MN6_2', 'target': 'Q31JZ2_2', 'score': 0.749}},
#  {'group': 'edges',
#   'data': {'source': 'Q31MN6_2', 'target': 'Q31QS5_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31MN6_2', 'target': 'Q31LT1_2', 'score': 0.766}},
#  {'group': 'edges',
#   'data': {'source': 'Q31MN6_2', 'target': 'Q31MG8_2', 'score': 0.836}},
#  {'group': 'edges',
#   'data': {'source': 'Q31MN6_2', 'target': 'Q9Z3G5_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31MN6_2', 'target': 'Q31LP4_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q8GJM0_2', 'target': 'Q31PN3_2', 'score': 0.62}},
#  {'group': 'edges',
#   'data': {'source': 'Q8GJM0_2', 'target': 'Q31N39_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q8GJM0_2', 'target': 'Q31K19_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q8GJM0_2', 'target': 'Q31PQ2_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q8GJM0_2', 'target': 'Q31MI8_2', 'score': 0.651}},
#  {'group': 'edges',
#   'data': {'source': 'Q8GJM0_2', 'target': 'Q31JZ2_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q8GJM0_2', 'target': 'Q31QS5_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q8GJM0_2', 'target': 'Q31LT1_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q8GJM0_2', 'target': 'Q31MG8_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q8GJM0_2', 'target': 'Q9Z3G5_2', 'score': 0.707}},
#  {'group': 'edges',
#   'data': {'source': 'Q8GJM0_2', 'target': 'Q31LP4_2', 'score': 0.682}},
#  {'group': 'edges',
#   'data': {'source': 'Q31PN3_2', 'target': 'Q31N39_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31PN3_2', 'target': 'Q31K19_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31PN3_2', 'target': 'Q31PQ2_2', 'score': 0.688}},
#  {'group': 'edges',
#   'data': {'source': 'Q31PN3_2', 'target': 'Q31MI8_2', 'score': 0.843}},
#  {'group': 'edges',
#   'data': {'source': 'Q31PN3_2', 'target': 'Q31JZ2_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31PN3_2', 'target': 'Q31QS5_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31PN3_2', 'target': 'Q31LT1_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31PN3_2', 'target': 'Q31MG8_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31PN3_2', 'target': 'Q9Z3G5_2', 'score': 0.691}},
#  {'group': 'edges',
#   'data': {'source': 'Q31PN3_2', 'target': 'Q31LP4_2', 'score': 0.706}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N39_2', 'target': 'Q31K19_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N39_2', 'target': 'Q31PQ2_2', 'score': 0.738}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N39_2', 'target': 'Q31MI8_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N39_2', 'target': 'Q31JZ2_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N39_2', 'target': 'Q31QS5_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N39_2', 'target': 'Q31LT1_2', 'score': 0.758}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N39_2', 'target': 'Q31MG8_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N39_2', 'target': 'Q9Z3G5_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N39_2', 'target': 'Q31LP4_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31K19_2', 'target': 'Q31PQ2_2', 'score': 0.72}},
#  {'group': 'edges',
#   'data': {'source': 'Q31K19_2', 'target': 'Q31MI8_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31K19_2', 'target': 'Q31JZ2_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31K19_2', 'target': 'Q31QS5_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31K19_2', 'target': 'Q31LT1_2', 'score': 0.78}},
#  {'group': 'edges',
#   'data': {'source': 'Q31K19_2', 'target': 'Q31MG8_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31K19_2', 'target': 'Q9Z3G5_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31K19_2', 'target': 'Q31LP4_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31PQ2_2', 'target': 'Q31MI8_2', 'score': 0.67}},
#  {'group': 'edges',
#   'data': {'source': 'Q31PQ2_2', 'target': 'Q31JZ2_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31PQ2_2', 'target': 'Q31QS5_2', 'score': 0.744}},
#  {'group': 'edges',
#   'data': {'source': 'Q31PQ2_2', 'target': 'Q31LT1_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31PQ2_2', 'target': 'Q31MG8_2', 'score': 0.766}},
#  {'group': 'edges',
#   'data': {'source': 'Q31PQ2_2', 'target': 'Q9Z3G5_2', 'score': 0.723}},
#  {'group': 'edges',
#   'data': {'source': 'Q31PQ2_2', 'target': 'Q31LP4_2', 'score': 0.64}},
#  {'group': 'edges',
#   'data': {'source': 'Q31MI8_2', 'target': 'Q31JZ2_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31MI8_2', 'target': 'Q31QS5_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31MI8_2', 'target': 'Q31LT1_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31MI8_2', 'target': 'Q31MG8_2', 'score': 0.679}},
#  {'group': 'edges',
#   'data': {'source': 'Q31MI8_2', 'target': 'Q9Z3G5_2', 'score': 0.733}},
#  {'group': 'edges',
#   'data': {'source': 'Q31MI8_2', 'target': 'Q31LP4_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31JZ2_2', 'target': 'Q31QS5_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31JZ2_2', 'target': 'Q31LT1_2', 'score': 0.768}},
#  {'group': 'edges',
#   'data': {'source': 'Q31JZ2_2', 'target': 'Q31MG8_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31JZ2_2', 'target': 'Q9Z3G5_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31JZ2_2', 'target': 'Q31LP4_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31QS5_2', 'target': 'Q31LT1_2', 'score': 0.768}},
#  {'group': 'edges',
#   'data': {'source': 'Q31QS5_2', 'target': 'Q31MG8_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31QS5_2', 'target': 'Q9Z3G5_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31QS5_2', 'target': 'Q31LP4_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LT1_2', 'target': 'Q31MG8_2', 'score': 0.796}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LT1_2', 'target': 'Q9Z3G5_2', 'score': 0.817}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LT1_2', 'target': 'Q31LP4_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31MG8_2', 'target': 'Q9Z3G5_2', 'score': 0.64}},
#  {'group': 'edges',
#   'data': {'source': 'Q31MG8_2', 'target': 'Q31LP4_2', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q9Z3G5_2', 'target': 'Q31LP4_2', 'score': 0.722}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LP0_3', 'target': 'P55020_3', 'score': 0.829}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LP0_3', 'target': 'Q31NA5_3', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'P55020_3', 'target': 'Q31NA5_3', 'score': 0.777}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q79PF4_4', 'score': 0.758}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31SC5_4', 'score': 0.957}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31NR2_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31NR1_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L23_4', 'score': 0.984}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L16_4', 'score': 0.956}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q59988_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31PL2_4', 'score': 0.788}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31MB5_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31K48_4', 'score': 0.602}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31N15_4', 'score': 0.681}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31S95_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31N52_4', 'score': 0.981}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31S72_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L21_4', 'score': 0.957}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31LX8_4', 'score': 0.613}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31N17_4', 'score': 0.733}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L15_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L09_4', 'score': 0.703}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L33_4', 'score': 0.913}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L35_4', 'score': 0.615}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31PV6_4', 'score': 0.968}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L07_4', 'score': 0.797}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31P66_4', 'score': 0.972}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31MH9_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31MB7_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31P67_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'P63200_4', 'score': 0.948}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L13_4', 'score': 0.994}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31KV8_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L29_4', 'score': 0.941}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L12_4', 'score': 0.773}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31KE9_4', 'score': 0.651}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L30_4', 'score': 0.882}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31QK6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q9Z3H5_4', 'score': 0.695}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q9Z3H6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31K30_4', 'score': 0.744}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L28_4', 'score': 0.992}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q9R6W2_4', 'score': 0.651}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31K59_4', 'score': 0.977}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31QK4_4', 'score': 0.918}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'P42079_4', 'score': 0.762}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L11_4', 'score': 0.975}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L17_4', 'score': 0.786}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31RE0_4', 'score': 0.773}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31PV3_4', 'score': 0.983}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'O33698_4', 'score': 0.942}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L10_4', 'score': 0.813}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L31_4', 'score': 0.895}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L08_4', 'score': 0.826}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L83_4', 'score': 0.739}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q79AV0_4', 'score': 0.934}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L18_4', 'score': 0.788}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'P31160_4', 'score': 0.874}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31QK3_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L20_4', 'score': 0.992}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L22_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31QE3_4', 'score': 0.949}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L34_4', 'target': 'Q31L19_4', 'score': 0.883}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31SC5_4', 'score': 0.613}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31NR2_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31NR1_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L23_4', 'score': 0.655}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L16_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q59988_4', 'score': 0.614}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31PL2_4', 'score': 0.723}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31MB5_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31K48_4', 'score': 0.631}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31N15_4', 'score': 0.649}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31S95_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31N52_4', 'score': 0.687}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31S72_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L21_4', 'score': 0.795}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31LX8_4', 'score': 0.744}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31N17_4', 'score': 0.677}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L15_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L09_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L33_4', 'score': 0.777}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L35_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31PV6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L07_4', 'score': 0.74}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31P66_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31MH9_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31MB7_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31P67_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'P63200_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L13_4', 'score': 0.735}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31KV8_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L29_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L12_4', 'score': 0.729}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31KE9_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L30_4', 'score': 0.69}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31QK6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q9Z3H5_4', 'score': 0.682}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q9Z3H6_4', 'score': 0.608}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31K30_4', 'score': 0.658}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L28_4', 'score': 0.816}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q9R6W2_4', 'score': 0.729}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31K59_4', 'score': 0.763}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31QK4_4', 'score': 0.823}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'P42079_4', 'score': 0.645}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L11_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L17_4', 'score': 0.77}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31RE0_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31PV3_4', 'score': 0.702}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'O33698_4', 'score': 0.616}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L10_4', 'score': 0.822}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L31_4', 'score': 0.864}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L08_4', 'score': 0.859}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L83_4', 'score': 0.683}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q79AV0_4', 'score': 0.59}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L18_4', 'score': 0.662}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'P31160_4', 'score': 0.857}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31QK3_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L20_4', 'score': 0.729}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L22_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31QE3_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q79PF4_4', 'target': 'Q31L19_4', 'score': 0.836}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31NR2_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31NR1_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L23_4', 'score': 0.887}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L16_4', 'score': 0.668}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q59988_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31PL2_4', 'score': 0.71}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31MB5_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31K48_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31N15_4', 'score': 0.619}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31S95_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31N52_4', 'score': 0.924}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31S72_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L21_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31LX8_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31N17_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L15_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L09_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L33_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L35_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31PV6_4', 'score': 0.921}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L07_4', 'score': 0.702}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31P66_4', 'score': 0.836}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31MH9_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31MB7_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31P67_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'P63200_4', 'score': 0.785}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L13_4', 'score': 0.933}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31KV8_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L29_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L12_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31KE9_4', 'score': 0.684}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L30_4', 'score': 0.636}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31QK6_4', 'score': 0.655}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q9Z3H5_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q9Z3H6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31K30_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L28_4', 'score': 0.961}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q9R6W2_4', 'score': 0.662}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31K59_4', 'score': 0.954}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31QK4_4', 'score': 0.691}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'P42079_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L11_4', 'score': 0.853}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L17_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31RE0_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31PV3_4', 'score': 0.922}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'O33698_4', 'score': 0.907}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L10_4', 'score': 0.699}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L31_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L08_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L83_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q79AV0_4', 'score': 0.816}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L18_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'P31160_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31QK3_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L20_4', 'score': 0.947}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L22_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31QE3_4', 'score': 0.895}},
#  {'group': 'edges',
#   'data': {'source': 'Q31SC5_4', 'target': 'Q31L19_4', 'score': 0.684}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31NR1_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L23_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L16_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q59988_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31PL2_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31MB5_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31K48_4', 'score': 0.885}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31N15_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31S95_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31N52_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31S72_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L21_4', 'score': 0.901}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31LX8_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31N17_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L15_4', 'score': 0.773}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L09_4', 'score': 0.748}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L33_4', 'score': 0.868}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L35_4', 'score': 0.672}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31PV6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L07_4', 'score': 0.899}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31P66_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31MH9_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31MB7_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31P67_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'P63200_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L13_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31KV8_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L29_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L12_4', 'score': 0.881}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31KE9_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L30_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31QK6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q9Z3H5_4', 'score': 0.793}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q9Z3H6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31K30_4', 'score': 0.782}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L28_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q9R6W2_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31K59_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31QK4_4', 'score': 0.897}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'P42079_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L11_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L17_4', 'score': 0.881}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31RE0_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31PV3_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'O33698_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L10_4', 'score': 0.905}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L31_4', 'score': 0.885}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L08_4', 'score': 0.882}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L83_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q79AV0_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L18_4', 'score': 0.84}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'P31160_4', 'score': 0.859}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31QK3_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L20_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L22_4', 'score': 0.711}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31QE3_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR2_4', 'target': 'Q31L19_4', 'score': 0.844}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L23_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L16_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q59988_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31PL2_4', 'score': 0.645}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31MB5_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31K48_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31N15_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31S95_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31N52_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31S72_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L21_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31LX8_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31N17_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L15_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L09_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L33_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L35_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31PV6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L07_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31P66_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31MH9_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31MB7_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31P67_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'P63200_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L13_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31KV8_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L29_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L12_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31KE9_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L30_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31QK6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q9Z3H5_4', 'score': 0.851}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q9Z3H6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31K30_4', 'score': 0.753}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L28_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q9R6W2_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31K59_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31QK4_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'P42079_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L11_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L17_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31RE0_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31PV3_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'O33698_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L10_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L31_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L08_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L83_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q79AV0_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L18_4', 'score': 0.688}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'P31160_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31QK3_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L20_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L22_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31QE3_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31NR1_4', 'target': 'Q31L19_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L16_4', 'score': 0.909}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q59988_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31PL2_4', 'score': 0.612}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31MB5_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31K48_4', 'score': 0.694}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31N15_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31S95_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31N52_4', 'score': 0.975}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31S72_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L21_4', 'score': 0.926}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31LX8_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31N17_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L15_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L09_4', 'score': 0.73}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L33_4', 'score': 0.906}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L35_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31PV6_4', 'score': 0.912}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L07_4', 'score': 0.728}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31P66_4', 'score': 0.941}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31MH9_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31MB7_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31P67_4', 'score': 0.77}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'P63200_4', 'score': 0.917}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L13_4', 'score': 0.986}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31KV8_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L29_4', 'score': 0.955}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L12_4', 'score': 0.966}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31KE9_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L30_4', 'score': 0.663}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31QK6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q9Z3H5_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q9Z3H6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31K30_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L28_4', 'score': 0.985}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q9R6W2_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31K59_4', 'score': 0.914}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31QK4_4', 'score': 0.782}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'P42079_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L11_4', 'score': 0.946}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L17_4', 'score': 0.862}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31RE0_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31PV3_4', 'score': 0.978}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'O33698_4', 'score': 0.836}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L10_4', 'score': 0.819}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L31_4', 'score': 0.89}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L08_4', 'score': 0.917}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L83_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q79AV0_4', 'score': 0.962}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L18_4', 'score': 0.809}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'P31160_4', 'score': 0.9}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31QK3_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L20_4', 'score': 0.989}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L22_4', 'score': 0.813}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31QE3_4', 'score': 0.831}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L23_4', 'target': 'Q31L19_4', 'score': 0.887}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q59988_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31PL2_4', 'score': 0.667}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31MB5_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31K48_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31N15_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31S95_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31N52_4', 'score': 0.943}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31S72_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31L21_4', 'score': 0.893}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31LX8_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31N17_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31L15_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31L09_4', 'score': 0.597}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31L33_4', 'score': 0.634}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31L35_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31PV6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31L07_4', 'score': 0.785}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31P66_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31MH9_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31MB7_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31P67_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'P63200_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31L13_4', 'score': 0.846}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31KV8_4', 'score': 0.632}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31L29_4', 'score': 0.856}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31L12_4', 'score': 0.761}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31KE9_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31L30_4', 'score': 0.708}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31QK6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q9Z3H5_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q9Z3H6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31K30_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31L28_4', 'score': 0.963}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q9R6W2_4', 'score': 0.639}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31K59_4', 'score': 0.89}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31QK4_4', 'score': 0.705}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'P42079_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31L11_4', 'score': 0.799}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31L17_4', 'score': 0.801}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31RE0_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31PV3_4', 'score': 0.873}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'O33698_4', 'score': 0.928}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31L10_4', 'score': 0.808}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31L31_4', 'score': 0.597}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31L08_4', 'score': 0.782}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31L83_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q79AV0_4', 'score': 0.784}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31L18_4', 'score': 0.808}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'P31160_4', 'score': 0.695}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31QK3_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31L20_4', 'score': 0.972}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31L22_4', 'score': 0.786}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31QE3_4', 'score': 0.902}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L16_4', 'target': 'Q31L19_4', 'score': 0.758}},
#  {'group': 'edges',
# ...
#   'data': {'source': 'Q31N52_4', 'target': 'Q31L21_4', 'score': 0.858}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31LX8_4', 'score': 0.614}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31N17_4', 'score': 0.678}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31L15_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31L09_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31L33_4', 'score': 0.824}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31L35_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31PV6_4', 'score': 0.948}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31L07_4', 'score': 0.675}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31P66_4', 'score': 0.978}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31MH9_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31MB7_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31P67_4', 'score': 0.686}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'P63200_4', 'score': 0.97}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31L13_4', 'score': 0.979}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31KV8_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31L29_4', 'score': 0.892}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31L12_4', 'score': 0.887}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31KE9_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31L30_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31QK6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q9Z3H5_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q9Z3H6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31K30_4', 'score': 0.668}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31L28_4', 'score': 0.99}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q9R6W2_4', 'score': 0.66}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31K59_4', 'score': 0.976}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31QK4_4', 'score': 0.815}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'P42079_4', 'score': 0.714}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31L11_4', 'score': 0.957}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31L17_4', 'score': 0.605}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31RE0_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31PV3_4', 'score': 0.966}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'O33698_4', 'score': 0.921}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31L10_4', 'score': 0.737}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31L31_4', 'score': 0.783}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31L08_4', 'score': 0.918}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31L83_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q79AV0_4', 'score': 0.942}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31L18_4', 'score': 0.72}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'P31160_4', 'score': 0.693}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31QK3_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31L20_4', 'score': 0.988}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31L22_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31QE3_4', 'score': 0.928}},
#  {'group': 'edges',
#   'data': {'source': 'Q31N52_4', 'target': 'Q31L19_4', 'score': 0.829}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31L21_4', 'score': 0.639}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31LX8_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31N17_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31L15_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31L09_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31L33_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31L35_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31PV6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31L07_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31P66_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31MH9_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31MB7_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31P67_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'P63200_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31L13_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31KV8_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31L29_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31L12_4', 'score': 0.629}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31KE9_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31L30_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31QK6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q9Z3H5_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q9Z3H6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31K30_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31L28_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q9R6W2_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31K59_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31QK4_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'P42079_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31L11_4', 'score': 0.656}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31L17_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31RE0_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31PV3_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'O33698_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31L10_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31L31_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31L08_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31L83_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q79AV0_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31L18_4', 'score': 0.656}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'P31160_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31QK3_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31L20_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31L22_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31QE3_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31S72_4', 'target': 'Q31L19_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31LX8_4', 'score': 0.93}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31N17_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31L15_4', 'score': 0.922}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31L09_4', 'score': 0.947}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31L33_4', 'score': 0.995}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31L35_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31PV6_4', 'score': 0.853}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31L07_4', 'score': 0.99}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31P66_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31MH9_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31MB7_4', 'score': 0.769}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31P67_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'P63200_4', 'score': 0.615}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31L13_4', 'score': 0.955}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31KV8_4', 'score': 0.751}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31L29_4', 'score': 0.834}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31L12_4', 'score': 0.991}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31KE9_4', 'score': 0.71}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31L30_4', 'score': 0.788}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31QK6_4', 'score': 0.898}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q9Z3H5_4', 'score': 0.96}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q9Z3H6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31K30_4', 'score': 0.924}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31L28_4', 'score': 0.949}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q9R6W2_4', 'score': 0.757}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31K59_4', 'score': 0.873}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31QK4_4', 'score': 0.99}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'P42079_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31L11_4', 'score': 0.868}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31L17_4', 'score': 0.988}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31RE0_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31PV3_4', 'score': 0.903}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'O33698_4', 'score': 0.719}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31L10_4', 'score': 0.988}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31L31_4', 'score': 0.971}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31L08_4', 'score': 0.988}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31L83_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q79AV0_4', 'score': 0.834}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31L18_4', 'score': 0.983}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'P31160_4', 'score': 0.995}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31QK3_4', 'score': 0.819}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31L20_4', 'score': 0.936}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31L22_4', 'score': 0.989}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31QE3_4', 'score': 0.744}},
#  {'group': 'edges',
#   'data': {'source': 'Q31L21_4', 'target': 'Q31L19_4', 'score': 0.988}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31N17_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31L15_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31L09_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31L33_4', 'score': 0.916}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31L35_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31PV6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31L07_4', 'score': 0.926}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31P66_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31MH9_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31MB7_4', 'score': 0.757}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31P67_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'P63200_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31L13_4', 'score': 0.684}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31KV8_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31L29_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31L12_4', 'score': 0.874}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31KE9_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31L30_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31QK6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q9Z3H5_4', 'score': 0.934}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q9Z3H6_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31K30_4', 'score': 0.85}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31L28_4', 'score': 0.711}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q9R6W2_4', 'score': 0.674}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31K59_4', 'score': 0.679}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31QK4_4', 'score': 0.952}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'P42079_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31L11_4', 'score': 0.713}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31L17_4', 'score': 0.92}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31RE0_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31PV3_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'O33698_4', 'score': 0.651}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31L10_4', 'score': 0.874}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31L31_4', 'score': 0.89}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31L08_4', 'score': 0.934}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q31L83_4', 'score': 0.5}},
#  {'group': 'edges',
#   'data': {'source': 'Q31LX8_4', 'target': 'Q79AV0_4', 'score': 0.5}},
#  ...]

# %%
cytoscapeobj.graph.add_graph_from_json(net_json)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 cytoscapeobj.graph.add_graph_from_json(net_json)
#
# File ~/opt/anaconda3/envs/phenome/lib/python3.9/site-packages/ipycytoscape/cytoscape.py:546, in Graph.add_graph_from_json(self, json_file, directed, multiple_edges)
#     543         json_file = json.load(f)
#     545 node_list = list()
# --> 546 for node in json_file["nodes"]:
#     547     node_instance = Node()
#     548     _set_attributes(node_instance, node)
#
# TypeError: list indices must be integers or slices, not str

# %%
net_json['nodes']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 net_json['nodes']
#
# TypeError: list indices must be integers or slices, not str
